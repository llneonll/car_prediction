# %% [markdown]
# <h2>Car price Prediction</h2>

# %% [markdown]
# <h4>importing libraries</h4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from dython.nominal import associations

# %% [markdown]
# <h4>importing data</h4>

# %%
df = pd.read_csv("CarPrice_Assignment.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# <h4>dataset info</h4>

# %%
# dataset size information
df.shape
# Out:
# (205, 26)

# %%
# datatype and null 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
# dataset info
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h4>Splitting car names for better relation on brands</h4>

# %%
df.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
CompanyName = df['CarName'].apply(lambda x : x.split(' ')[0])
df.insert(3,"CompanyName",CompanyName)

# %%
df.head(10)
# Out:
#    car_ID  symboling                   CarName  CompanyName fueltype  \
# 0       1          3        alfa-romero giulia  alfa-romero      gas
# 1       2          3       alfa-romero stelvio  alfa-romero      gas
# 2       3          1  alfa-romero Quadrifoglio  alfa-romero      gas
# 3       4          2               audi 100 ls         audi      gas
# 4       5          2                audi 100ls         audi      gas
# 5       6          2                  audi fox         audi      gas
# 6       7          1                audi 100ls         audi      gas
# 7       8          1                 audi 5000         audi      gas
# 8       9          1                 audi 4000         audi      gas
# 9      10          0       audi 5000s (diesel)         audi      gas
#
#   aspiration doornumber      carbody drivewheel enginelocation  ...  \
# 0        std        two  convertible        rwd          front  ...
# 1        std        two  convertible        rwd          front  ...
# 2        std        two    hatchback        rwd          front  ...
# 3        std       four        sedan        fwd          front  ...
# 4        std       four        sedan        4wd          front  ...
# 5        std        two        sedan        fwd          front  ...
# 6        std       four        sedan        fwd          front  ...
# 7        std       four        wagon        fwd          front  ...
# 8      turbo       four        sedan        fwd          front  ...
# 9      turbo        two    hatchback        4wd          front  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio horsepower  \
# 0         130        mpfi       3.47    2.68               9.0        111
# 1         130        mpfi       3.47    2.68               9.0        111
# 2         152        mpfi       2.68    3.47               9.0        154
# 3         109        mpfi       3.19    3.40              10.0        102
# 4         136        mpfi       3.19    3.40               8.0        115
# 5         136        mpfi       3.19    3.40               8.5        110
# 6         136        mpfi       3.19    3.40               8.5        110
# 7         136        mpfi       3.19    3.40               8.5        110
# 8         131        mpfi       3.13    3.40               8.3        140
# 9         131        mpfi       3.13    3.40               7.0        160
#
#   peakrpm  citympg highwaympg      price
# 0    5000       21         27  13495.000
# 1    5000       21         27  16500.000
# 2    5000       19         26  16500.000
# 3    5500       24         30  13950.000
# 4    5500       18         22  17450.000
# 5    5500       19         25  15250.000
# 6    5500       19         25  17710.000
# 7    5500       19         25  18920.000
# 8    5500       17         20  23875.000
# 9    5500       16         22  17859.167
#
# [10 rows x 27 columns]

# %%
df.shape
# Out:
# (205, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   CompanyName       205 non-null    object
#  4   fueltype          205 non-null    object
#  5   aspiration        205 non-null    object
#  6   doornumber        205 non-null    object
#  7   carbody           205 non-null    object
#  8   drivewheel        205 non-null    object
#  9   enginelocation    205 non-null    object
#  10  wheelbase         205 non-null    float64
#  11  carlength         205 non-null    float64
#  12  carwidth          205 non-null    float64
#  13  carheight         205 non-null    float64
#  14  curbweight        205 non-null    int64
#  15  enginetype        205 non-null    object
#  16  cylindernumber    205 non-null    object
#  17  enginesize        205 non-null    int64
#  18  fuelsystem        205 non-null    object
#  19  boreratio         205 non-null    float64
#  20  stroke            205 non-null    float64
#  21  compressionratio  205 non-null    float64
#  22  horsepower        205 non-null    int64
#  23  peakrpm           205 non-null    int64
#  24  citympg           205 non-null    int64
#  25  highwaympg        205 non-null    int64
#  26  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(11)
# memory usage: 43.4+ KB

# %% [markdown]
# <h4>Outlier and inconsistency</h4>

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
object_list = df.select_dtypes(include=['object']).columns.to_list()
object_list
# histogram or bar chart
# Out:
# ['CarName',
#  'CompanyName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
for value in object_list:
    print(value,df[value].unique())
# Out:
# CarName ['alfa-romero giulia' 'alfa-romero stelvio' 'alfa-romero Quadrifoglio'
#  'audi 100 ls' 'audi 100ls' 'audi fox' 'audi 5000' 'audi 4000'
#  'audi 5000s (diesel)' 'bmw 320i' 'bmw x1' 'bmw x3' 'bmw z4' 'bmw x4'
#  'bmw x5' 'chevrolet impala' 'chevrolet monte carlo' 'chevrolet vega 2300'
#  'dodge rampage' 'dodge challenger se' 'dodge d200' 'dodge monaco (sw)'
#  'dodge colt hardtop' 'dodge colt (sw)' 'dodge coronet custom'
#  'dodge dart custom' 'dodge coronet custom (sw)' 'honda civic'
#  'honda civic cvcc' 'honda accord cvcc' 'honda accord lx'
#  'honda civic 1500 gl' 'honda accord' 'honda civic 1300' 'honda prelude'
#  'honda civic (auto)' 'isuzu MU-X' 'isuzu D-Max ' 'isuzu D-Max V-Cross'
#  'jaguar xj' 'jaguar xf' 'jaguar xk' 'maxda rx3' 'maxda glc deluxe'
#  'mazda rx2 coupe' 'mazda rx-4' 'mazda glc deluxe' 'mazda 626' 'mazda glc'
#  'mazda rx-7 gs' 'mazda glc 4' 'mazda glc custom l' 'mazda glc custom'
#  'buick electra 225 custom' 'buick century luxus (sw)' 'buick century'
#  'buick skyhawk' 'buick opel isuzu deluxe' 'buick skylark'
#  'buick century special' 'buick regal sport coupe (turbo)'
#  'mercury cougar' 'mitsubishi mirage' 'mitsubishi lancer'
#  'mitsubishi outlander' 'mitsubishi g4' 'mitsubishi mirage g4'
#  'mitsubishi montero' 'mitsubishi pajero' 'Nissan versa' 'nissan gt-r'
#  'nissan rogue' 'nissan latio' 'nissan titan' 'nissan leaf' 'nissan juke'
#  'nissan note' 'nissan clipper' 'nissan nv200' 'nissan dayz' 'nissan fuga'
#  'nissan otti' 'nissan teana' 'nissan kicks' 'peugeot 504' 'peugeot 304'
#  'peugeot 504 (sw)' 'peugeot 604sl' 'peugeot 505s turbo diesel'
#  'plymouth fury iii' 'plymouth cricket' 'plymouth satellite custom (sw)'
#  'plymouth fury gran sedan' 'plymouth valiant' 'plymouth duster'
#  'porsche macan' 'porcshce panamera' 'porsche cayenne' 'porsche boxter'
#  'renault 12tl' 'renault 5 gtl' 'saab 99e' 'saab 99le' 'saab 99gle'
#  'subaru' 'subaru dl' 'subaru brz' 'subaru baja' 'subaru r1' 'subaru r2'
#  'subaru trezia' 'subaru tribeca' 'toyota corona mark ii' 'toyota corona'
#  'toyota corolla 1200' 'toyota corona hardtop' 'toyota corolla 1600 (sw)'
#  'toyota carina' 'toyota mark ii' 'toyota corolla'
#  'toyota corolla liftback' 'toyota celica gt liftback'
#  'toyota corolla tercel' 'toyota corona liftback' 'toyota starlet'
#  'toyota tercel' 'toyota cressida' 'toyota celica gt' 'toyouta tercel'
#  'vokswagen rabbit' 'volkswagen 1131 deluxe sedan' 'volkswagen model 111'
#  'volkswagen type 3' 'volkswagen 411 (sw)' 'volkswagen super beetle'
#  'volkswagen dasher' 'vw dasher' 'vw rabbit' 'volkswagen rabbit'
#  'volkswagen rabbit custom' 'volvo 145e (sw)' 'volvo 144ea' 'volvo 244dl'
#  'volvo 245' 'volvo 264gl' 'volvo diesel' 'volvo 246']
# CompanyName ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'maxda' 'mazda' 'buick' 'mercury' 'mitsubishi' 'Nissan' 'nissan'
#  'peugeot' 'plymouth' 'porsche' 'porcshce' 'renault' 'saab' 'subaru'
#  'toyota' 'toyouta' 'vokswagen' 'volkswagen' 'vw' 'volvo']
# fueltype ['gas' 'diesel']
# aspiration ['std' 'turbo']
# doornumber ['two' 'four']
# carbody ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# drivewheel ['rwd' 'fwd' '4wd']
# enginelocation ['front' 'rear']
# enginetype ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# cylindernumber ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# fuelsystem ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']

# %%
fig, ax = plt.subplots(figsize=(15, 30))
sns.barplot(y=object_list[0], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='CarName'>

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(y=object_list[1], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='CompanyName'>

# %%
sns.barplot(y=object_list[2], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='fueltype'>

# %%
sns.barplot(y=object_list[3], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='aspiration'>

# %%
sns.barplot(y=object_list[4], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='doornumber'>

# %%
sns.barplot(y=object_list[5], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='carbody'>

# %%
sns.barplot(y=object_list[6], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='drivewheel'>

# %%
sns.barplot(y=object_list[7], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='enginelocation'>

# %%
sns.barplot(y=object_list[8], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='enginetype'>

# %%
sns.barplot(y=object_list[9], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='cylindernumber'>

# %%
sns.barplot(y=object_list[10], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='fuelsystem'>

# %%
df['fuelsystem'].value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
non_object_list = df.select_dtypes(exclude=['object']).columns.to_list()
non_object_list
# box plot or scatter plot
# Out:
# ['car_ID',
#  'symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
# Symboling
sns.boxplot(x = df[non_object_list[1]])
# Out:
# <AxesSubplot:xlabel='symboling'>

# %%
#Wheelbase
sns.boxplot(x = df['wheelbase'])
# Out:
# <AxesSubplot:xlabel='wheelbase'>

# %%
sns.scatterplot(y=df['wheelbase'], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='wheelbase'>

# %%
#carlength
sns.boxplot(x = df['carlength'])
# Out:
# <AxesSubplot:xlabel='carlength'>

# %%
sns.scatterplot(y=df['wheelbase'], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='wheelbase'>

# %%
# carwidth 
sns.boxplot(x = df['carwidth'])
# Out:
# <AxesSubplot:xlabel='carwidth'>

# %%
# carheight
sns.boxplot(x = df['carheight'])
# Out:
# <AxesSubplot:xlabel='carheight'>

# %%
# curbweight
sns.boxplot(x = df['curbweight'])
# Out:
# <AxesSubplot:xlabel='curbweight'>

# %%
# enginesize
sns.boxplot(x = df['enginesize'])
# Out:
# <AxesSubplot:xlabel='enginesize'>

# %%
# boreratio
sns.boxplot(x = df['boreratio'])
# Out:
# <AxesSubplot:xlabel='boreratio'>

# %%
# stroke
sns.boxplot(x = df['stroke'])
# Out:
# <AxesSubplot:xlabel='stroke'>

# %%
# compressionratio
sns.boxplot(x = df['compressionratio'])
# Out:
# <AxesSubplot:xlabel='compressionratio'>

# %%
# horsepower
sns.boxplot(x = df['horsepower'])
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.scatterplot(y=df['horsepower'], x="price", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='horsepower'>

# %%
# peakrpm
sns.boxplot(x = df['peakrpm'])
# Out:
# <AxesSubplot:xlabel='peakrpm'>

# %%
# citympg
sns.boxplot(x = df['citympg'])
# Out:
# <AxesSubplot:xlabel='citympg'>

# %%
# highwaymp
sns.boxplot(x = df['highwaympg'])
# Out:
# <AxesSubplot:xlabel='highwaympg'>

# %%
corr_matrix = df.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_85234_row0_col0, #T_85234_row1_col1, #T_85234_row2_col2, #T_85234_row3_col3, #T_85234_row4_col4, #T_85234_row5_col5, #T_85234_row6_col6, #T_85234_row7_col7, #T_85234_row8_col8, #T_85234_row9_col9, #T_85234_row10_col10, #T_85234_row11_col11, #T_85234_row12_col12, #T_85234_row13_col13, #T_85234_row14_col14, #T_85234_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_85234_row0_col1, #T_85234_row3_col9 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_85234_row0_col2, #T_85234_row0_col4, #T_85234_row0_col11 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_85234_row0_col3, #T_85234_row9_col4, #T_85234_row10_col2, #T_85234_row10_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_85234_row0_col5, #T_85234_row12_col11 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_85234_row0_col6, #T_85234_row1_col11, #T_85234_row5_col15 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_85234_row0_col7, #T_85234_row5_col11, #T_85234_row5_col14, #T_85234_row8_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_85234_row0_col8, #T_85234_row4_col5 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_85234_row0_col9, #T_85234_row1_col5, #T_85234_row5_col1, #T_85234_row6_col14, #T_85234_row10_col12, #T_85234_row11_col13, #T_85234_row12_col0, #T_85234_row12_col10, #T_85234_row13_col8, #T_85234_row13_col11, #T_85234_row14_col2, #T_85234_row14_col3, #T_85234_row14_col4, #T_85234_row14_col6, #T_85234_row14_col7, #T_85234_row14_col8, #T_85234_row14_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_85234_row0_col10, #T_85234_row6_col10 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_85234_row0_col12, #T_85234_row11_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_85234_row0_col13, #T_85234_row9_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_85234_row0_col14, #T_85234_row10_col15 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_85234_row0_col15, #T_85234_row9_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_85234_row1_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_85234_row1_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_85234_row1_col3, #T_85234_row6_col1, #T_85234_row15_col9 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_85234_row1_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_85234_row1_col6, #T_85234_row13_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_85234_row1_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_85234_row1_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_85234_row1_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_85234_row1_col10, #T_85234_row14_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_85234_row1_col12 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_85234_row1_col13 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_85234_row1_col14, #T_85234_row8_col5 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_85234_row1_col15 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_85234_row2_col0, #T_85234_row2_col9 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_85234_row2_col1, #T_85234_row13_col15 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_85234_row2_col3, #T_85234_row4_col6, #T_85234_row6_col3, #T_85234_row7_col15 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_85234_row2_col4, #T_85234_row2_col6 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_85234_row2_col5, #T_85234_row5_col2, #T_85234_row11_col8 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_85234_row2_col7 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_85234_row2_col8 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_85234_row2_col10, #T_85234_row5_col8 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_85234_row2_col11 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_85234_row2_col12, #T_85234_row3_col14 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_85234_row2_col13 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_85234_row2_col14, #T_85234_row7_col0, #T_85234_row12_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_85234_row2_col15, #T_85234_row3_col8, #T_85234_row3_col11, #T_85234_row8_col7 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_85234_row3_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_85234_row3_col1, #T_85234_row6_col12, #T_85234_row8_col13, #T_85234_row12_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_85234_row3_col2, #T_85234_row6_col4 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_85234_row3_col4, #T_85234_row6_col15 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_85234_row3_col5, #T_85234_row8_col2 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_85234_row3_col6 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_85234_row3_col7 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_85234_row3_col10, #T_85234_row12_col14 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_85234_row3_col12, #T_85234_row13_col9 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_85234_row3_col13 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_85234_row3_col15, #T_85234_row7_col3, #T_85234_row15_col3 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_85234_row4_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_85234_row4_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_85234_row4_col2 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_85234_row4_col3, #T_85234_row15_col6 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_85234_row4_col7, #T_85234_row7_col4 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_85234_row4_col8, #T_85234_row7_col2 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_85234_row4_col9, #T_85234_row10_col0, #T_85234_row12_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_85234_row4_col10, #T_85234_row15_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_85234_row4_col11 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_85234_row4_col12 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_85234_row4_col13 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_85234_row4_col14, #T_85234_row7_col14 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_85234_row4_col15, #T_85234_row15_col4 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_85234_row5_col0, #T_85234_row12_col13 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_85234_row5_col3 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_85234_row5_col4 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_85234_row5_col6 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_85234_row5_col7 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_85234_row5_col9, #T_85234_row8_col9 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_85234_row5_col10, #T_85234_row14_col10 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_85234_row5_col12, #T_85234_row12_col9, #T_85234_row15_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_85234_row5_col13 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_85234_row6_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_85234_row6_col2 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_85234_row6_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_85234_row6_col7 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_85234_row6_col8 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_85234_row6_col9, #T_85234_row7_col1, #T_85234_row14_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_85234_row6_col11, #T_85234_row11_col6 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_85234_row6_col13 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_85234_row7_col5, #T_85234_row11_col1, #T_85234_row11_col12 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_85234_row7_col6 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_85234_row7_col8, #T_85234_row8_col4, #T_85234_row8_col15, #T_85234_row11_col3 {
#   background-color: #f59f80;
#   c

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, annot=True, cmap=plt.cm.CMRmap_r)
# Out:
# <AxesSubplot:>

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(df, 0.7)
len(set(corr_features))
# Out:
# 8

# %%
corr_features
# Out:
# {'carlength',
#  'carwidth',
#  'citympg',
#  'curbweight',
#  'enginesize',
#  'highwaympg',
#  'horsepower',
#  'price'}

# %%
cg = sns.clustermap(corr_matrix, cmap ="YlGnBu", linewidths = 0.1);
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)
plt.show()
